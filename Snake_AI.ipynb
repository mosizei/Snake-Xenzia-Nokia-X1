# %% [markdown]
# # Snake AI with PyTorch

# %% [markdown]
# ## 1. Setup Environment

# %%
# !pip install torch torchvision

# %% [markdown]
# ## 2. Clone the repository

# %%
# !git clone <your_repository_url>

# %%
import sys
sys.path.append('/content/your_repository_name')

# %% [markdown]
# ## 3. Train the Model

# %%
from snake_game.train import train
train()

# %% [markdown]
# ## 4. Visualize Training Progress

# %%
import pandas as pd
import matplotlib.pyplot as plt

log_df = pd.read_csv('training_log.csv')
plt.figure(figsize=(10, 6))
plt.plot(log_df['episode'], log_df['reward'])
plt.title('Training Progress')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.grid(True)
plt.show()
